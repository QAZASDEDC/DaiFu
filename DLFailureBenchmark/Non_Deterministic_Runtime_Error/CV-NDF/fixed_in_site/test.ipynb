# %%
import os

relative_path = '../../'
absolute_path = os.path.abspath(relative_path)

# %%
import sys
sys.path.insert(0, absolute_path)

# %%
sys.path
# Out:
# ['/home/user/hzl/DaiFu/DLFailureBenchmark/Non_Deterministic_Runtime_Error',
#  '',
#  '/home/user/hzl/DaiFu/DLFailureBenchmark/Non_Deterministic_Runtime_Error/CV-NDF/fixed_in_site',
#  '/home/user/anaconda3/envs/torch-1.7/lib/python37.zip',
#  '/home/user/anaconda3/envs/torch-1.7/lib/python3.7',
#  '/home/user/anaconda3/envs/torch-1.7/lib/python3.7/lib-dynload',
#  '/home/user/anaconda3/envs/torch-1.7/lib/python3.7/site-packages',
#  '/home/user/anaconda3/envs/torch-1.7/lib/python3.7/site-packages/IPython/extensions',
#  '/home/user/.ipython']

# %%
import torch
import inspect
inspect.getsourcefile(torch)
# Out:
# '/home/user/hzl/DaiFu/DLFailureBenchmark/Non_Deterministic_Runtime_Error/torch/__init__.py'
